# %% [markdown]
# ## Importing Libraries

# %%
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as layers

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
tf.__version__
# Out:
# '2.11.0'

# %% [markdown]
# ## Loading Data

# %%
(X_train , y_train) ,(X_test , y_test) = tf.keras.datasets.fashion_mnist.load_data()

print('Fashion MNIST Dataset Shape:')
print('X_train: ' + str(X_train.shape))
print('Y_train: ' + str(y_train.shape))
print('X_test:  '  + str(X_test.shape))
print('Y_test:  '  + str(y_test.shape))
# Out:
# Fashion MNIST Dataset Shape:
# X_train: (60000, 28, 28)
# Y_train: (60000,)
# X_test:  (10000, 28, 28)
# Y_test:  (10000,)

# %% [markdown]
# ## Plotting

# %%
sample = 5

img = X_train[sample]

plt.imshow(img)
plt.show()

# %% [markdown]
# ## Scaling

# %%
X_train = X_train/255.0
X_test = X_test/255.0

# %% [markdown]
# ## Modeling

# %%
model = keras.models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128 , activation ="relu" , name ="layer_1"),
    layers.Dense(10 , activation ="softmax" , name ="layer_final")
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  layer_1 (Dense)             (None, 128)               100480
#
#  layer_final (Dense)         (None, 10)                1290
#
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compiling Model

# %%
model.compile(optimizer='adam' , loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ## Training

# %%
myModel = model.fit(x = X_train , y = y_train ,validation_data =(X_test , y_test) , epochs = 10 )
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1710 - accuracy: 0.9364 - val_loss: 0.3438 - val_accuracy: 0.8891
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1675 - accuracy: 0.9370 - val_loss: 0.3559 - val_accuracy: 0.8877
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1619 - accuracy: 0.9390 - val_loss: 0.3435 - val_accuracy: 0.8951
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1589 - accuracy: 0.9413 - val_loss: 0.3826 - val_accuracy: 0.8897
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1540 - accuracy: 0.9424 - val_loss: 0.3752 - val_accuracy: 0.8877
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1521 - accuracy: 0.9427 - val_loss: 0.3885 - val_accuracy: 0.8869
# Epoch 7/10
# ...

# %% [markdown]
# ## Visualizing Test And Train

# %%
plt.plot(myModel.history['accuracy'] , label = 'train')
plt.plot(myModel.history['val_accuracy'] , label = 'test')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('FashionMnist Dataset ')
plt.show()

# %% [markdown]
# ## Modeling with 10 norun

# %%
model = keras.models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(10 , activation ="relu" , name ="layer_1"),
    layers.Dense(10 , activation ="softmax" , name ="layer_final")
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 784)               0
#
#  layer_1 (Dense)             (None, 10)                7850
#
#  layer_final (Dense)         (None, 10)                110
#
# ...
# Total params: 7,960
# Trainable params: 7,960
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam' , loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
myModel = model.fit(x = X_train , y = y_train ,validation_data =(X_test , y_test) , epochs = 10 )
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6712 - accuracy: 0.7649 - val_loss: 0.5262 - val_accuracy: 0.8132
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4478 - accuracy: 0.8425 - val_loss: 0.4837 - val_accuracy: 0.8277
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4173 - accuracy: 0.8527 - val_loss: 0.4673 - val_accuracy: 0.8333
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4020 - accuracy: 0.8593 - val_loss: 0.4413 - val_accuracy: 0.8482
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3929 - accuracy: 0.8606 - val_loss: 0.4466 - val_accuracy: 0.8442
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3840 - accuracy: 0.8655 - val_loss: 0.4455 - val_accuracy: 0.8424
# Epoch 7/10
# ...

# %%
plt.plot(myModel.history['accuracy'] , label = 'train')
plt.plot(myModel.history['val_accuracy'] , label = 'test')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('FashionMnist Dataset ')
plt.show()
